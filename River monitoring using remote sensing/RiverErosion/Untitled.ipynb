# %% [markdown]
# # Importing Library

# %%
from PIL import Image, ImageChops
from matplotlib import pyplot as plt

# %% [markdown]
# # Assign images

# %%
img1 = Image.open("Data/Jamuna river data1973.png")
#img2 = Image.open("Jamuna river data1973.png")

img2 = Image.open("Data/Jamuna river data1980.png")

plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()

# %% [markdown]
# # Finding the difference

# %%
diff = ImageChops.difference(img1, img2)

# %% [markdown]
# # Output

# %%
#diff.show()
plt.imshow(diff)
plt.show()
